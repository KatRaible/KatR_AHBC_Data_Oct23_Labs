# %%
import pandas as pd


df_CSV = pd.read_csv('/home/Data Analytics/wta_matches_2022.csv')

print(df_CSV.head())

df_tsv = pd.read_csv("/home/Data Analytics/wta_matches_2022.tsv", delimiter='\t')

print(df_tsv.head())

df_xls = pd.read_excel("wta_matches_2022.xlsx")

print(df_xls.head())

df_parquet = pd.read_parquet("wta_matches_2022.parquet") 

summary = df_parquet.describe()
print(summary)

# %time data_csv = pd.read_csv('/home/Data Analytics/wta_matches_2022.csv')
# %time data_tsv = pd.read_csv("/home/Data Analytics/wta_matches_2022.tsv", delimiter='\t')
# %time data_parquet = pd.read_parquet("wta_matches_2022.parquet")
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2022-2014   Adelaide 1    Hard         30             P      20220103
# 1  2022-2014   Adelaide 1    Hard         30             P      20220103
# 2  2022-2014   Adelaide 1    Hard         30             P      20220103
# 3  2022-2014   Adelaide 1    Hard         30             P      20220103
# 4  2022-2014   Adelaide 1    Hard         30             P      20220103
#
#    match_num  winner_id winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     202458           1          NaN  ...    19.0     16.0
# 1        299     202458           1          NaN  ...    39.0     27.0
# 2        298     214981           7          NaN  ...    45.0     29.0
# 3        297     202458           1          NaN  ...    54.0     34.0
# 4        296     216347           5          NaN  ...    45.0     30.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced winner_rank winner_rank_points  \
# ...
